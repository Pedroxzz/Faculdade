# %% [markdown]
# # EXERCÍCIOS

# %% [markdown]
# 7.   Carregue um vetor com 5 números e mostre o menor deles.
# 8.   Faça download do arquivo **"base-dados-funcionários"**, que se encontra na sala de aula do Classroom, sob número: **qif5j5t**. Abra este arquivo no Python e crie uma lista para cada coluna do Datraframe. Em seguida, crie um dicionário onde a chave seja o **nome** e o valor seja a **idade** do funcionário. Mostre o conteúdo do dicionário no final.

# %%
#7

import random

vet = []
for i in range(5):
  n = 0
  n = input(f'Digite o valor do {i+1}º número: ')
  vet.append(n)
min(vet)
# Out:
# '-0'

# %%
#8

import pandas as pd

dados = pd.read_excel('C:./base-dados-funcionarios.xlsx')

nomeFunc = list(dados['NOME'])
idadeFunc = list(dados['IDADE'])
profFunc = list(dados['PROFISSAO'])
salFunc = list(dados['SALARIO'])

func = dict()

for i in range(18):
    func[nomeFunc[i]] = idadeFunc[i]

for k,v in func.items():
    print(f'{k}: {v}')
# Out:
# Luana: 18
# Paulo: 19
# Cláudio: 56
# Virginia: 34
# Lurdes: 45
# Maria: 44
# Nestor: 32
# Alexandre: 36
# Misael: 59
# Gustavo: 40
# Diana: 56
# Fernando: 17
# Isabela: 76
# Virgínia: 32
# Talita: 39
# Marcos: 59
# Geraldo: 23
# Monique: 21
